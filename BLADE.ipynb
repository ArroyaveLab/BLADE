# %%
from materialsframework.calculators import GraceCalculator as Calculator
from materialsframework.tools.sqs2tdb import Sqs2tdb
from blade.blade_compositions import BladeCompositions
from blade.blade_sqs import BladeSQS
from blade.blade_phase_diagram import BladePhaseDiagram
import matplotlib.pyplot as plt
from pycalphad import Database, binplot, ternplot
from pycalphad import variables as v, binplot
import pycalphad.variables as v
import os

# %%
# N_THREADS = 8
# os.environ["OMP_NUM_THREADS"] = str(N_THREADS)
# os.environ["MKL_NUM_THREADS"] = str(N_THREADS)
# os.environ["OPENBLAS_NUM_THREADS"] = str(N_THREADS)
# torch.set_num_threads(N_THREADS)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
phase = 'HEDB1'
liquid = True
liquid = False
path = '/Users/chasekatz/Desktop/School/Research'
path1 = os.path.join(path, 'PhaseForge/PhaseForge/atat/data/sqsdb/')
path2 = os.path.join(path, 'MF_tests/p9/')
level = 6
time = 30

# %%
# Specify elements and system size (Total # elements)
transition_metals = ["Ti", "Zr", "Hf", "V", "Nb", "Ta", "Cr", "Mo", "W"]
rare_earths = ["Sc", "Y", "La", "Pr", "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu"]
system_size = 2
tm_element_range = [2, 2]
re_element_range = [0, 0]
allow_lower_order = True
allow_lower_order = False

# %%
comp_gen = BladeCompositions(transition_metals, rare_earths, system_size, 
                                 tm_min=tm_element_range[0], tm_max=tm_element_range[1], 
                                 re_min=re_element_range[0], re_max=re_element_range[1], 
                                 allow_lower_order=allow_lower_order)

compositions = comp_gen.generate_compositions()

unique_len_comps = comp_gen.get_systems()

print("Total # compositions: ", compositions)
print("Unique length compositions: ", unique_len_comps)
# Out:
# [['Cr', 'Hf'], ['Cr', 'Mo'], ['Cr', 'Nb'], ['Cr', 'Ta'], ['Cr', 'Ti'], ['Cr', 'V'], ['Cr', 'W'], ['Cr', 'Zr'], ['Hf', 'Mo'], ['Hf', 'Nb'], ['Hf', 'Ta'], ['Hf', 'Ti'], ['Hf', 'V'], ['Hf', 'W'], ['Hf', 'Zr'], ['Mo', 'Nb'], ['Mo', 'Ta'], ['Mo', 'Ti'], ['Mo', 'V'], ['Mo', 'W'], ['Mo', 'Zr'], ['Nb', 'Ta'], ['Nb', 'Ti'], ['Nb', 'V'], ['Nb', 'W'], ['Nb', 'Zr'], ['Ta', 'Ti'], ['Ta', 'V'], ['Ta', 'W'], ['Ta', 'Zr'], ['Ti', 'V'], ['Ti', 'W'], ['Ti', 'Zr'], ['V', 'W'], ['V', 'Zr'], ['W', 'Zr']]
# Total compositions: 36
# Unique: 36
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# Unique Systems: {2}
# Total # compositions:  [['Cr', 'Hf'], ['Cr', 'Mo'], ['Cr', 'Nb'], ['Cr', 'Ta'], ['Cr', 'Ti'], ['Cr', 'V'], ['Cr', 'W'], ['Cr', 'Zr'], ['Hf', 'Mo'], ['Hf', 'Nb'], ['Hf', 'Ta'], ['Hf', 'Ti'], ['Hf', 'V'], ['Hf', 'W'], ['Hf', 'Zr'], ['Mo', 'Nb'], ['Mo', 'Ta'], ['Mo', 'Ti'], ['Mo', 'V'], ['Mo', 'W'], ['Mo', 'Zr'], ['Nb', 'Ta'], ['Nb', 'Ti'], ['Nb', 'V'], ['Nb', 'W'], ['Nb', 'Zr'], ['Ta', 'Ti'], ['Ta', 'V'], ['Ta', 'W'], ['Ta', 'Zr'], ['Ti', 'V'], ['Ti', 'W'], ['Ti', 'Zr'], ['V', 'W'], ['V', 'Zr'], ['W', 'Zr']]
# Unique length compositions:  {2}

# %%
a = 1
b = 1
c = 1.63299
alpha = 90
beta = 90
gamma = 120

rndstr = """
0.000000 0.000000 0.000000  a
0.333333 0.666667 0.000000  a
0.666667 0.333333 0.000000  a
0.500000 0.000000 0.000000  a
0.000000 0.500000 0.000000  a
0.500000 0.500000 0.000000  a
0.250000 0.750000 0.000000  a
0.166667 0.833333 0.5       B
0.833333 0.166667 0.5       B
0.250000 0.250000 0.5       B
0.750000 0.750000 0.5       B
0.600000 0.300000 0.5       B
0.300000 0.600000 0.5       B
0.000000 0.000000 1.000000  a
0.333333 0.666667 1.000000  a
0.666667 0.333333 1.000000  a
0.500000 0.000000 1.000000  a
0.000000 0.500000 1.000000  a
0.500000 0.500000 1.000000  a
0.250000 0.750000 1.000000  a
"""

sqsgen_levels = [
"""level=0         a=1""", 
"""level=1         a=0.5,0.5""",
"""level=2         a=0.75,0.25""",
"""level=3         a=0.33333,0.33333,0.33333""",
"""level=4         a=0.5,0.25,0.25""",
"""level=5         a=0.875,0.125\nlevel=5         a=0.625,0.375""",
"""level=6         a=0.75,0.125,0.125"""]

# %%
sqs_gen = BladeSQS(a, b, c, alpha, beta, gamma, rndstr, sqsgen_levels, level)

# %%
struct, sqs_struct = sqs_gen.sqs_struct()

# %%
fraction = "0.75, 0.125, 0.125"
fractions = [float(x) for x in fraction.split(",")]
N_atoms, counts = sqs_gen.supercell_size(fractions)
print(N_atoms, counts)
# Out:
# 80 [42, 7, 7]

# %%
sqs_gen.sqs_gen(unique_len_comps, phase, path, path1, time)
# Out:
# f.write(rndstr) /Users/chasekatz/Desktop/School/Research/MF_tests/p9
# File created at: /Users/chasekatz/Desktop/School/Research/PhaseForge/PhaseForge/atat/data/sqsdb/HEDB1_2/rndstr.skel
# f.write(sqsgen) /Users/chasekatz/Desktop/School/Research/MF_tests/p9
# File created at: /Users/chasekatz/Desktop/School/Research/PhaseForge/PhaseForge/atat/data/sqsdb/HEDB1_2/sqsgen.in
# result = subprocess.run(cmd, cwd=dir_name, capture_output=True, text=True) /Users/chasekatz/Desktop/School/Research/PhaseForge/PhaseForge/atat/data/sqsdb/HEDB1_2
# sqsdb_lev=0_a=1
# sqsdb_lev=1_a=0.5,0.5
# sqsdb_lev=2_a=0.75,0.25
# sqsdb_lev=3_a=0.33333,0.33333,0.33333
# sqsdb_lev=4_a=0.5,0.25,0.25
# sqsdb_lev=5_a=0.875,0.125
# sqsdb_lev=5_a=0.625,0.375
# sqsdb_lev=6_a=0.75,0.125,0.125
# Directories setup
#
# for sqsdir in parent_dir.glob('sqsdb_lev=*/'): /Users/chasekatz/Desktop/School/Research/MF_tests/p9
# Running corrdump in [0.33333, 0.33333, 0.33333]
# Running mcsqs with 60 atoms in [0.33333, 0.33333, 0.33333]
# touch stopsqs in [0.33333, 0.33333, 0.33333] after 30 seconds
# Running corrdump in [0.75, 0.125, 0.125]
# Running mcsqs with 80 atoms in [0.75, 0.125, 0.125]
# touch stopsqs in [0.75, 0.125, 0.125] after 30 seconds
# Running corrdump in [0.875, 0.125]
# Running mcsqs with 80 atoms in [0.875, 0.125]
# touch stopsqs in [0.875, 0.125] after 30 seconds
# Running corrdump in [0.625, 0.375]
# Running mcsqs with 80 atoms in [0.625, 0.375]
# touch stopsqs in [0.625, 0.375] after 30 seconds
# Running corrdump in [0.75, 0.25]
# Running mcsqs with 40 atoms in [0.75, 0.25]
# touch stopsqs in [0.75, 0.25] after 30 seconds
# [1.0]
# Skipping pure species directory: /Users/chasekatz/Desktop/School/Research/PhaseForge/PhaseForge/atat/data/sqsdb/HEDB1_2/sqsdb_lev=0_a=1
# Running corrdump in [0.5, 0.5]
# Running mcsqs with 20 atoms in [0.5, 0.5]
# touch stopsqs in [0.5, 0.5] after 30 seconds
# Running corrdump in [0.5, 0.25, 0.25]
# Running mcsqs with 40 atoms in [0.5, 0.25, 0.25]
# touch stopsqs in [0.5, 0.25, 0.25] after 30 seconds

# %%
def sqsfit_func(comp, phases, level):
    # Initialize the wrapper
    #sqs = Sqs2tdb(fmax=0.001, verbose=True, calculator=Calculator(device="cpu"), md_timestep=100, md_temperature=2000)
    sqs = Sqs2tdb(fmax=0.01, verbose=True, calculator=Calculator(device="cpu"))

    # Fit SQS for Ni-Re system on FCC_A1 and HCP_A3 lattices
    sqs.fit(
        species=comp,
        lattices=phases,
        level=level,
        T_max=4000,
    )

def plot(tdb, elements, phases, file):
    fig = plt.figure(figsize=(9,7))
    axes = fig.gca()

    # Compute the phase diagram and plot it
    binplot(
        tdb, elements, phases,
        {v.X(elements[0]): (0, 1, 0.02), v.T: (1, 4000, 10), v.P: 101325, v.N: 1},
        plot_kwargs={'ax': axes}
    )
    plt.tight_layout()
    plt.savefig(f'{file}_Phase_Diagram.png', dpi=300)

# %%
phasediagram = BladePhaseDiagram(compositions, liquid, path2, phase)

# %%
for comp in compositions:
    main_dir, file, phases = phasediagram.directory(comp)
    print(file)
    os.chdir(file)
    sqsfit_func(comp, phases, level)

    file_names, elements = phasediagram.file_names(comp)
    # Load database and choose the phases that will be considered

    for file in file_names:
        if os.path.isfile(f'{file}.tdb'):
            tdb = Database(f'{file}.tdb')
            plot(tdb, elements, phases, file)

    # Change back to main folder
    os.chdir(main_dir)
# Out:
# /Users/chasekatz/Desktop/School/Research/MF_tests/p9/CrHf
# STDOUT: Using species: Cr,Hf
# Preparing sqs_lev=2_a_Cr=0.75,a_Hf=0.25 directory
# Preparing sqs_lev=2_a_Cr=0.25,a_Hf=0.75 directory
# Preparing sqs_lev=5_a_Cr=0.875,a_Hf=0.125 directory
# Preparing sqs_lev=5_a_Cr=0.125,a_Hf=0.875 directory
# Preparing sqs_lev=5_a_Cr=0.625,a_Hf=0.375 directory
# Preparing sqs_lev=5_a_Cr=0.375,a_Hf=0.625 directory
# Copied SQSs
# STDERR: sh: -c: line 0: syntax error near unexpected token `&'
# sh: -c: line 0: `cellcvrt -sym < sqs_lev=2_a_Cr=0.75,a_Hf=0.25/str.in |& grep -v Warning | head -n 1'
# sh: -c: line 0: syntax error near unexpected token `&'
# sh: -c: line 0: `cellcvrt -sym < sqs_lev=2_a_Cr=0.25,a_Hf=0.75/str.in |& grep -v Warning | head -n 1'
# sh: -c: line 0: syntax error near unexpected token `&'
# sh: -c: line 0: `cellcvrt -sym < sqs_lev=5_a_Cr=0.875,a_Hf=0.125/str.in |& grep -v Warning | head -n 1'
# sh: -c: line 0: syntax error near unexpected token `&'
# sh: -c: line 0: `cellcvrt -sym < sqs_lev=5_a_Cr=0.125,a_Hf=0.875/str.in |& grep -v Warning | head -n 1'
# sh: -c: line 0: syntax error near unexpected token `&'
# sh: -c: line 0: `cellcvrt -sym < sqs_lev=5_a_Cr=0.625,a_Hf=0.375/str.in |& grep -v Warning | head -n 1'
# sh: -c: line 0: syntax error near unexpected token `&'
# sh: -c: line 0: `cellcvrt -sym < sqs_lev=5_a_Cr=0.375,a_Hf=0.625/str.in |& grep -v Warning | head -n 1'
# STDOUT: Using species: Cr,Hf
# Copied SQSs
# STDERR:
# STDOUT:
# STDERR: zcat: can't stat: /usr/local/lib/paw_pbe/B/POTCAR.Z (/usr/local/lib/paw_pbe/B/POTCAR.Z.gz): No such file or directory
# zcat: can't stat: /usr/local/lib/paw_pbe/Cr/POTCAR.Z (/usr/local/lib/paw_pbe/Cr/POTCAR.Z.gz): No such file or directory
# zcat: can't stat: /usr/local/lib/paw_pbe/Hf/POTCAR.Z (/usr/local/lib/paw_pbe/Hf/POTCAR.Z.gz): No such file or directory
# HEDB1_2/sqs_lev=5_a_Cr=0.625,a_Hf=0.375
# Using cached GRACE model from /Users/chasekatz/.cache/grace/GRACE-2L-OMAT
# Model license: Academic Software License
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768603722.569366 10919658 service.cc:145] XLA service 0x37a79be00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1768603722.569677 10919658 service.cc:153]   StreamExecutor device (0): Host, Default Version
# 2026-01-16 16:48:42.764991: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#       Step     Time          Energy          fmax
# FIRE:    0 16:48:45     -168.237183        2.193517
# I0000 00:00:1768603725.407036 10919658 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# FIRE:    1 16:48:45     -168.626860        2.219158
# FIRE:    2 16:48:46     -169.406151        2.253581
# FIRE:    3 16:48:46     -170.565707        2.246589
# FIRE:    4 16:48:46     -171.774483        2.130695
# FIRE:    5 16:48:46     -172.916909        1.839563
# FIRE:    6 16:48:46     -173.928393        1.312576
# FIRE:    7 16:48:47     -174.720573        1.327791
# FIRE:    8 16:48:47     -175.266158        1.827698
# FIRE:    9 16:48:47     -175.693780        2.710800
# FIRE:   10 16:48:47     -176.296381        3.649897
# FIRE:   11 16:48:47     -177.266646        2.542435
# FIRE:   12 16:48:48     -178.269654        2.968681
# FIRE:   13 16:48:48     -179.223202        1.962004
# FIRE:   14 16:48:48     -180.051128        1.947728
# FIRE:   15 16:48:48     -180.849244        1.813846
# FIRE:   16 16:48:48     -181.638334        1.481287
# FIRE:   17 16:48:49     -182.417388        1.284692
# FIRE:   18 16:48:49     -183.182963        1.224672
# FIRE:   19 16:48:49     -183.958315        1.971577
# FIRE:   20 16:48:49     -184.838200        2.490211
# FIRE:   21 16:48:49     -185.832407        2.448144
# FIRE:   22 16:48:50     -186.891900        1.980688
